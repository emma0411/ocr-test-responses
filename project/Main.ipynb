# %% [markdown]
# # OCR circles
#
# - Añadir indicaciones

# %%
import logging
import os
from google import genai
from utils import gemini_key
import main

# configure genai clients
clients = [genai.Client(api_key=k) for k in gemini_key.gemini_api_key]
#model_id = "gemini-2.5-pro"
model_id = "gemini-2.5-flash"

# process images in the folder
main.process_ocr(path = '../archivos', model_id = model_id, clients = clients)
# Out:
# 2025-12-25 22:16:33,630 - INFO - Processing file: test.jpeg
# 2025-12-25 22:16:33,659 - INFO - Return without resize.
# 2025-12-25 22:16:33,664 - INFO - Return without resize.
# 2025-12-25 22:16:33,665 - INFO - AFC is enabled with max remote calls: 10.
# 2025-12-25 22:16:45,383 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 200 OK"
# 2025-12-25 22:16:45,388 - INFO - Successful response from image and text with model gemini-2.5-flash
# 2025-12-25 22:16:45,388 - INFO - AFC is enabled with max remote calls: 10.
# 2025-12-25 22:16:53,813 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 200 OK"
# 2025-12-25 22:16:53,818 - INFO - Successful response from image and text with model gemini-2.5-flash
# 2025-12-25 22:16:53,958 - INFO - Response saved to cuestionario_20251225_221653.xlsx
